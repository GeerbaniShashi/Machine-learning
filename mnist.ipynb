# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation = "relu"),
    layers.Dense(10, activation = "softmax")
])

# %%
model.compile(optimizer="rmsprop",
loss = "sparse_categorical_crossentropy",
metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 5s 9ms/step - loss: 0.2622 - accuracy: 0.9256
# Epoch 2/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1074 - accuracy: 0.9681
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0709 - accuracy: 0.9786
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0518 - accuracy: 0.9840
# Epoch 5/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0384 - accuracy: 0.9888

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 [==============================] - 0s 81ms/step
# array([4.1716078e-08, 1.8496494e-09, 5.4635697e-05, 8.6406704e-05,
#        1.6998266e-11, 3.8448103e-08, 3.6906741e-13, 9.9985790e-01,
#        1.6251650e-07, 7.3642531e-07], dtype=float32)

# %%
test_labels[0]
# Out:
# 7

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0630 - accuracy: 0.9814
# test_acc: 0.9814000129699707
