# %%
n = int(input())
print(n)
# Out:
# 5
# 5

# %%
print('Hello World')
print("Double quotes")
print('conceatenat'+'ion')
print('Hello','there')
print('I am' , 5)
print('I\'m 5')
print("I\'m 5")
print('He said "Hi"')
# Out:
# Hello World
# Double quotes
# conceatenation
# Hello there
# I am 5
# I'm 5
# I'm 5
# He said "Hi"

# %%
1+3
print(1+3)
print(1-3)
print(1*3)
print(1/3)
print(1.5/3.6)
4**2
print(4**2)
# Out:
# 4
# -2
# 3
# 0.3333333333333333
# 0.41666666666666663
# 16

# %%
exVar = 100
print(exVar)
# Out:
# 100

# %%
exVar = '100'
print(exVar)
# Out:
# 100

# %%
exVar = 100
print(exVar)
opVar = exVar/5.3
print(opVar)
_100ma = 5
print(_100ma)
# Out:
# 100
# 18.867924528301888
# 5

# %%
condition = 1
while condition < 10:
  print(condition)
  condition += 1
  #condition = condition + 1
  '''
  multiple 
  lines
  can
  go 
  here 
  ''' 
  #condition = 5
  #while condition < 15:
    #print('True')
  #while True:
    #print('infinite')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
