# %%
import pandas as pd
import numpy as np

# %%
l1 = [2,5,8,6,8,9,4,6]
l1[0]
# Out:
# 2

# %%
d1={'a':2,'b':5}

# %%
for i in enumerate(l1):
    print(i)
# Out:
# (0, 2)
# (1, 5)
# (2, 8)
# (3, 6)
# (4, 8)
# (5, 9)
# (6, 4)
# (7, 6)

# %%
for i in enumerate(d1):    print(i)
# Out:
# (0, 'a')
# (1, 'b')

# %%
 for i,j in enumerate(l1):    print(i,j)
# Out:
# 0 2
# 1 5
# 2 8
# 3 6
# 4 8
# 5 9
# 6 4
# 7 6

# %%
pd.Series(l1)
# Out:
# 0    2
# 1    5
# 2    8
# 3    6
# 4    8
# 5    9
# 6    4
# 7    6
# dtype: int64

# %%
s1 = pd.Series((3,4,5),index=['a','b','c'])
s1
# Out:
# a    3
# b    4
# c    5
# dtype: int64

# %%
dt = { 'a':3,'b':4,'c':5}
dt
# Out:
# {'a': 3, 'b': 4, 'c': 5}

# %%
t1 = (3,4,5)

# %%
s1 = pd.Series(t1,index = ['a','b','c'])
s1
# Out:
# a    3
# b    4
# c    5
# dtype: int64

# %%
lt = [4,'hi','hello',8,45]
s3 = pd.Series(lt)
s3
# Out:
# 0        4
# 1       hi
# 2    hello
# 3        8
# 4       45
# dtype: object

# %%
lt = [4,'hi','hello',8,45]
s3 = pd.Series(lt, index = ['h','i','j','k','l'])
s3
# Out:
# h        4
# i       hi
# j    hello
# k        8
# l       45
# dtype: object

# %%
t1 = pd.Series([3,4,5], index = ['a','b','c'])
t2 = pd.Series([3,5,8], index = ['a','b','c'])

# %%
t1+t2
# Out:
# a     6
# b     9
# c    13
# dtype: int64

# %%
s1 = pd.Series([3,4,5], index = ['a','b','c'])
s2 = pd.Series([3,5,8], index = ['a','b','d'])
s1 + s2
# Out:
# a    6.0
# b    9.0
# c    NaN
# d    NaN
# dtype: float64

# %%
s1
# Out:
# a    3
# b    4
# c    5
# dtype: int64

# %%
s1[2]
# Out:
# 5

# %%
s1['a']
# Out:
# 3

# %%
s1['c']
# Out:
# 5

# %%
s3
# Out:
# 0        4
# 1       hi
# 2    hello
# 3        8
# 4       45
# dtype: object

# %%
s3[0:3]
# Out:
# 0        4
# 1       hi
# 2    hello
# dtype: object

# %%
s3['h':'k']
# Out:
# h        4
# i       hi
# j    hello
# k        8
# dtype: object

# %%
s3[['h','j','l']]
# Out:
# h        4
# j    hello
# l       45
# dtype: object

# %%
s3
# Out:
# h        4
# i       hi
# j    hello
# k        8
# l       45
# dtype: object

# %%
veg = pd.Series({'potato':3,'tomato':6,'chilly':2,'pumpkin':8,'carrot':10,'radish':4})
veg
# Out:
# potato      3
# tomato      6
# chilly      2
# pumpkin     8
# carrot     10
# radish      4
# dtype: int64

# %%
veg.values
# Out:
# array([ 3,  6,  2,  8, 10,  4])

# %%
veg.index
# Out:
# Index(['potato', 'tomato', 'chilly', 'pumpkin', 'carrot', 'radish'], dtype='object')

# %%
veg.shape
# Out:
# (6,)

# %%
veg.index
# Out:
# Index(['potato', 'tomato', 'chilly', 'pumpkin', 'carrot', 'radish'], dtype='object')

# %%
veg.shape
# Out:
# (6,)

# %%
veg
# Out:
# potato      3
# tomato      6
# chilly      2
# pumpkin     8
# carrot     10
# radish      4
# dtype: int64

# %%
veg[0]
# Out:
# 3

# %%
veg['carrot']
# Out:
# 10

# %%
veg['pumpkin':'radish']
# Out:
# pumpkin     8
# carrot     10
# radish      4
# dtype: int64

# %%
veg[1:4]
# Out:
# tomato     6
# chilly     2
# pumpkin    8
# dtype: int64

# %%
veg[['tomato','radish','pumpkin']]
# Out:
# tomato     6
# radish     4
# pumpkin    8
# dtype: int64

# %%
veg['tomato':]
# Out:
# tomato      6
# chilly      2
# pumpkin     8
# carrot     10
# radish      4
# dtype: int64

# %%
veg[:'pumpkin']
# Out:
# potato     3
# tomato     6
# chilly     2
# pumpkin    8
# dtype: int64

# %%
veg[1:4]
# Out:
# tomato     6
# chilly     2
# pumpkin    8
# dtype: int64

# %%
veg[1::2]
# Out:
# tomato     6
# pumpkin    8
# radish     4
# dtype: int64

# %%
veg[1::3]
# Out:
# tomato     6
# carrot    10
# dtype: int64

# %%
veg
# Out:
# potato      3
# tomato      6
# chilly      2
# pumpkin     8
# carrot     10
# radish      4
# dtype: int64

# %%
#iloc/loc
#loc:label based indexing
#iloc: position based indexing
