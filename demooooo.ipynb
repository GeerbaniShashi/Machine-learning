# %%
a = 5
b = 6
c = a+b
print(c)
# Out:
# 11

# %%
d = a*b
print(d)
# Out:
# 30

# %%
a = 5
b = 6
c = a+b
d = a-b
e = a*b
f=a/b
print(a,b,c,d,e,f)
# Out:
# 5 6 11 -1 30 0.8333333333333334

# %%
import imutils
imutils.__version__
# Out:
# '0.5.4'

# %%
import numpy
numpy.__version__
# Out:
# '1.23.5'

# %% [markdown]
# Demo Python program

# %%
a = 5

# %%
b =  6
c = a+b
print(c)
# Out:
# 11
