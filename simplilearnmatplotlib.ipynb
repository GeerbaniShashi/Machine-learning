# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.22.4

# %%
import numpy as np
x = np.linspace(0,10,25)
y = x*x + 2
print(x)
print(y)
print(np.array([x,y]).reshape(25,2))
print(np.array([x,y]).reshape(25,2).reshape(2,25))
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
pylab.plot(x,y,'b')
pylab.plot(x,y,'r')
pylab.plot(x,y,'y')

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--')
pylab.subplot(1,2,2)
pylab.plot(x,y,'g*-')
pylab.subplot(1,2,2)
pylab.plot(y,x,'g*-')
pylab.subplot(2,3,3)
pylab.plot(y,x,'g*-')
# Out:
# <ipython-input-4-e7d9eef57c04>:7: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   pylab.subplot(2,3,3)

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
axes = fig.add_axes([0.5,0.1,0.8,0.8])
axes.plot(x,y,'r')

# %%
n = np.array([0,1,2,3,4,5])
fig, axes = plt.subplots(1, 4, figsize=(16,5))

axes[0].set_title("scatter")
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))

axes[1].set_title("step")
axes[1].step(n , n**2, lw=2)

axes[2].set_title("bar")
axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)

axes[3].set_title("fill_between")
axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0,0.0,0.6,0.6], polar = True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t,t,color='blue', lw=3)

# %%
n = np.random.randn(100000)
fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=50)
# Out:
# (array([3.0000e+00, 4.0000e+00, 8.0000e+00, 1.8000e+01, 3.7000e+01,
#         6.7000e+01, 1.2500e+02, 2.1700e+02, 3.8400e+02, 6.3200e+02,
#         1.0530e+03, 1.5730e+03, 2.3530e+03, 3.4480e+03, 4.8680e+03,
#         6.8850e+03, 9.3050e+03, 1.2334e+04, 1.5995e+04, 2.0387e+04,
#         2.5322e+04, 3.0980e+04, 3.7074e+04, 4.3435e+04, 4.9970e+04,
#         5.6436e+04, 6.2808e+04, 6.8982e+04, 7.4552e+04, 7.9632e+04,
#         8.4021e+04, 8.7731e+04, 9.0798e+04, 9.3248e+04, 9.5164e+04,
#         9.6650e+04, 9.7706e+04, 9.8467e+04, 9.9033e+04, 9.9380e+04,
#         9.9596e+04, 9.9780e+04, 9.9870e+04, 9.9932e+04, 9.9961e+04,
#         9.9981e+04, 9.9987e+04, 9.9994e+04, 9.9997e+04, 1.0000e+05]),
#  array([-4.13424950e+00, -3.96879760e+00, -3.80334570e+00, -3.63789380e+00,
#         -3.47244190e+00, -3.30699000e+00, -3.14153810e+00, -2.97608620e+00,
#         -2.81063430e+00, -2.64518240e+00, -2.47973050e+00, -2.31427860e+00,
#         -2.14882669e+00, -1.98337479e+00, -1.81792289e+00, -1.65247099e+00,
#         -1.48701909e+00, -1.32156719e+00, -1.15611529e+00, -9.90663393e-01,
#         -8.25211492e-01, -6.59759592e-01, -4.94307692e-01, -3.28855792e-01,
#         -1.63403891e-01,  2.04800901e-03,  1.67499909e-01,  3.32951810e-01,
#          4.98403710e-01,  6.63855610e-01,  8.29307510e-01,  9.94759411e-01,
#          1.16021131e+00,  1.32566321e+00,  1.49111511e+00,  1.65656701e+00,
#          1.82201891e+00,  1.98747081e+00,  2.15292271e+00,  2.31837461e+00,
#          2.48382651e+00,  2.64927841e+00,  2.81473031e+00,  2.98018221e+00,
#          3.14563411e+00,  3.31108601e+00,  3.47653792e+00,  3.64198982e+00,
#          3.80744172e+00,  3.97289362e+00,  4.13834552e+00]),
#  <BarContainer object of 50 artists>)

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0,3.0,delta)
y = np.arange(-2.0,2.0,delta)
X,Y = np.meshgrid(x,y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y-1)**2)

Z = (Z1- Z2) * 2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X,Y,Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

ax = fig.add_subplot(1,2,1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)
